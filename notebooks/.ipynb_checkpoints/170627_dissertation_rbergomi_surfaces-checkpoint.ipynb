# %% [markdown]
# rBergomi: generating surface for dissertation
# ==

# %% [markdown]
# $$S_t = \mathcal{E} \left\{ \int_0^t \sqrt{ V_u } \ \mathrm{d} \ (\rho W^1_u + \bar{\rho} W^2_u) \right\}, \quad V_t = \xi \ \mathcal{E} \left\{ \eta \sqrt{2\alpha + 1} \int_0^t (t - u)^\alpha \mathrm{d}W^1_u \right\},$$

# %%
import os
os.chdir('/Users/ryanmccrickerd/Desktop/phd/2016-17/turbo_rbergomi/rbergomi')

# %%
import numpy as np
from matplotlib import pyplot as plt
# import matplotlib.mlab as mlab
from rbergomi import rBergomi
# from surface import Surface
from routines import generate_surface
% matplotlib inline

# %%
from surface import Surface
surface = Surface('surface', 'base', close = False)

# %%
surface.surface
# Out:
#           5P       10P       15P       20P       25P       30P       35P  \
# 1D  0.324548  0.295867  0.278527  0.265714  0.255337  0.246528  0.238823
# 1W  0.332202  0.299343  0.279773  0.265418  0.253893  0.244151  0.235702
# 1M  0.335236  0.299439  0.278203  0.262749  0.250429  0.240083  0.231134
# 3M  0.333202  0.296052  0.274017  0.258037  0.245360  0.234788  0.225659
# 6M  0.328794  0.291462  0.269242  0.253180  0.240494  0.229950  0.220844
# 1Y  0.321039  0.284210  0.262220  0.246376  0.233928  0.223565  0.214633
#
#          40P       45P       ATM       45C       40C       35C       30C  \
# 1D  0.231842  0.225386  0.219606  0.213549  0.207946  0.202434  0.196966
# 1W  0.228103  0.221110  0.215340  0.208425  0.202493  0.196720  0.191033
# 1M  0.223156  0.215858  0.210680  0.202695  0.196624  0.190776  0.185066
# 3M  0.217556  0.210161  0.206085  0.196941  0.190900  0.185136  0.179553
# 6M  0.212772  0.205431  0.202469  0.192372  0.186444  0.180820  0.175414
# ...

# %%
k = np.array(surface._log_strike_surface())
MV = np.array(surface.surface)

plot, axes = plt.subplots(figsize=(4,2.5))

axes.plot(k[0,:], MV[0,:], 'r')
axes.plot(k[1,:], MV[1,:], 'm')
axes.plot(k[2,:], MV[2,:], 'y')
axes.plot(k[3,:], MV[3,:], 'g')
axes.plot(k[4,:], MV[4,:], 'c')
axes.plot(k[5,:], MV[5,:], 'b')

axes.set_xlabel(r'$k$', fontsize = 16)
axes.set_ylabel(r'$\sigma_{BS}(k,t)$', fontsize = 16)
axes.set_title(r'$\rho = -0.9, \quad \alpha = -0.43$', fontsize = 16)
axes.legend([r'$\mathsf{1D}$',
             r'$\mathsf{1W}$',
             r'$\mathsf{1M}$',
             r'$\mathsf{3M}$',
             r'$\mathsf{6M}$',
             r'$\mathsf{1Y}$'], prop={'size':9})
plt.xlim([-0.5,0.301])
plt.ylim([0.10,0.35])
plt.grid(True)

fname = '/Users/ryanmccrickerd/Desktop/phd/2017-18/turbo/surface0.pdf'
plt.savefig(fname, dpi=300, bbox_inches='tight')

# %%
k = np.array(surface._forward_deltas())
MV = np.array(surface.surface)

plot, axes = plt.subplots(figsize=(4,2.5))

axes.plot(k[0,:], MV[0,:], 'r')
axes.plot(k[1,:], MV[1,:], 'm')
axes.plot(k[2,:], MV[2,:], 'y')
axes.plot(k[3,:], MV[3,:], 'g')
axes.plot(k[4,:], MV[4,:], 'c')
axes.plot(k[5,:], MV[5,:], 'b')

axes.set_xlabel(r'$\Delta$', fontsize = 16)
axes.set_ylabel(r'$\sigma_{BS}(\Delta,t)$', fontsize = 16)
axes.set_title(r'$\rho = -0.9, \quad \alpha = -0.43$', fontsize = 16)
axes.legend([r'$\mathsf{1D}$',
             r'$\mathsf{1W}$',
             r'$\mathsf{1M}$',
             r'$\mathsf{3M}$',
             r'$\mathsf{6M}$',
             r'$\mathsf{1Y}$'], prop={'size':9})
plt.xlim([0,1])
plt.ylim([0.10,0.35])
plt.grid(True)

fname = '/Users/ryanmccrickerd/Desktop/phd/2017-18/turbo/surface4.pdf'
plt.savefig(fname, dpi=300, bbox_inches='tight')

# %%
surface = Surface('surface', 'rho', close = False)
surface.surface
# Out:
#           5P       10P       15P       20P       25P       30P       35P  \
# 1D  0.249896  0.240369  0.235294  0.232007  0.229702  0.228047  0.226882
# 1W  0.253366  0.241360  0.234971  0.230818  0.227958  0.225862  0.224404
# 1M  0.256179  0.241863  0.234261  0.229313  0.225897  0.223430  0.221723
# 3M  0.257699  0.241656  0.233083  0.227538  0.223711  0.221002  0.219143
# 6M  0.257997  0.240905  0.231805  0.225925  0.221880  0.219051  0.217124
# 1Y  0.257284  0.239356  0.229820  0.223689  0.219499  0.216603  0.214665
#
#          40P       45P       ATM       45C       40C       35C       30C  \
# 1D  0.226100  0.225635  0.225500  0.225668  0.226166  0.226977  0.228174
# 1W  0.223434  0.222894  0.222751  0.222989  0.223636  0.224698  0.226270
# 1M  0.220616  0.220018  0.219889  0.220261  0.221100  0.222462  0.224432
# 3M  0.217949  0.217362  0.217273  0.217839  0.218903  0.220575  0.222930
# 6M  0.215927  0.215385  0.215338  0.216112  0.217373  0.219299  0.221987
# ...

# %%
k = np.array(surface._log_strike_surface())
MV = np.array(surface.surface)

plot, axes = plt.subplots(figsize=(4,2.5))

axes.plot(k[0,:], MV[0,:], 'r')
axes.plot(k[1,:], MV[1,:], 'm')
axes.plot(k[2,:], MV[2,:], 'y')
axes.plot(k[3,:], MV[3,:], 'g')
axes.plot(k[4,:], MV[4,:], 'c')
axes.plot(k[5,:], MV[5,:], 'b')

axes.set_xlabel(r'$k$', fontsize = 16)
axes.set_ylabel(r'$\sigma_{BS}(k,t)$', fontsize = 16)
axes.set_title(r'$\rho = 0, \quad \alpha = -0.43$', fontsize = 16)
# axes.legend([r'$\mathsf{1D}$',
#              r'$\mathsf{1W}$',
#              r'$\mathsf{1M}$',
#              r'$\mathsf{3M}$',
#              r'$\mathsf{6M}$',
#              r'$\mathsf{1Y}$'])

plt.xlim([-0.4,0.4])
plt.ylim([0.20,0.28])
axes.yaxis.set_ticks(np.arange(0.2, 0.28, 0.02))
plt.grid(True)

fname = '/Users/ryanmccrickerd/Desktop/phd/2017-18/turbo/surface1.pdf'
plt.savefig(fname, dpi=300, bbox_inches='tight')

# %%
k = np.array(surface._forward_deltas())
MV = np.array(surface.surface)

plot, axes = plt.subplots(figsize=(4,2.5))

axes.plot(k[0,:], MV[0,:], 'r')
axes.plot(k[1,:], MV[1,:], 'm')
axes.plot(k[2,:], MV[2,:], 'y')
axes.plot(k[3,:], MV[3,:], 'g')
axes.plot(k[4,:], MV[4,:], 'c')
axes.plot(k[5,:], MV[5,:], 'b')

axes.set_xlabel(r'$\Delta$', fontsize = 16)
axes.set_ylabel(r'$\sigma_{BS}(\Delta,t)$', fontsize = 16)
axes.set_title(r'$\rho = 0, \quad \alpha = -0.43$', fontsize = 16)
# axes.legend([r'$\mathsf{1D}$',
#              r'$\mathsf{1W}$',
#              r'$\mathsf{1M}$',
#              r'$\mathsf{3M}$',
#              r'$\mathsf{6M}$',
#              r'$\mathsf{1Y}$'])

plt.xlim([0,1])
plt.ylim([0.20,0.28])
axes.yaxis.set_ticks(np.arange(0.2, 0.28, 0.02))
plt.grid(True)

fname = '/Users/ryanmccrickerd/Desktop/phd/2017-18/turbo/surface5.pdf'
plt.savefig(fname, dpi=300, bbox_inches='tight')

# %% [markdown]
# Now must produce the same two charts but with rho = 0 to show how alpha explodes everything

# %% [markdown]
# Need to scale on same axis. Unless new charts are unexpected this should paint a nice narrative of the model as regards SPX at least.

# %%
surface = Surface('surface', 'alpha', close = False)
surface.surface
# Out:
#           5P       10P       15P       20P       25P       30P       35P  \
# 1D  0.244491  0.242386  0.240967  0.239853  0.238892  0.238011  0.237198
# 1W  0.257916  0.252346  0.248643  0.245752  0.243300  0.241107  0.239098
# 1M  0.281569  0.268646  0.260304  0.253884  0.248580  0.243917  0.239726
# 3M  0.309786  0.285267  0.270017  0.258579  0.249358  0.241444  0.234454
# 6M  0.327352  0.292081  0.270761  0.255138  0.242742  0.232335  0.223275
# 1Y  0.331084  0.285103  0.258135  0.238879  0.223850  0.211487  0.200888
#
#          40P       45P       ATM       45C       40C       35C       30C  \
# 1D  0.236447  0.235729  0.235053  0.234304  0.233583  0.232832  0.232063
# 1W  0.237229  0.235456  0.233939  0.231999  0.230280  0.228507  0.226675
# 1M  0.235855  0.232212  0.229628  0.225296  0.221917  0.218495  0.214983
# 3M  0.228114  0.222227  0.219069  0.211349  0.206163  0.201030  0.195830
# 6M  0.215170  0.207755  0.204784  0.194330  0.188065  0.181962  0.175886
# ...

# %%
k = np.array(surface._log_strike_surface())
MV = np.array(surface.surface)

plot, axes = plt.subplots(figsize=(4,2.5))

axes.plot(k[0,:], MV[0,:], 'r')
axes.plot(k[1,:], MV[1,:], 'm')
axes.plot(k[2,:], MV[2,:], 'y')
axes.plot(k[3,:], MV[3,:], 'g')
axes.plot(k[4,:], MV[4,:], 'c')
axes.plot(k[5,:], MV[5,:], 'b')

axes.set_xlabel(r'$k$', fontsize = 16)
axes.set_ylabel(r'$\sigma_{BS}(k,t)$', fontsize = 16)
axes.set_title(r'$\rho = -0.9,\quad \alpha = 0$', fontsize = 16)
# axes.legend([r'$\mathsf{1D}$',
#              r'$\mathsf{1W}$',
#              r'$\mathsf{1M}$',
#              r'$\mathsf{3M}$',
#              r'$\mathsf{6M}$',
#              r'$\mathsf{1Y}$'])
plt.xlim([-0.5,0.301])
plt.ylim([0.10,0.35])
plt.grid(True)

fname = '/Users/ryanmccrickerd/Desktop/phd/2017-18/turbo/surface2.pdf'
plt.savefig(fname, dpi=300, bbox_inches='tight')

# %%
k = np.array(surface._put_deltas())
MV = np.array(surface.surface)

plot, axes = plt.subplots(dpi=10000, figsize=(4,2.5))

axes.plot(k[0,:], MV[0,:], 'r')
axes.plot(k[1,:], MV[1,:], 'm')
axes.plot(k[2,:], MV[2,:], 'y')
axes.plot(k[3,:], MV[3,:], 'g')
axes.plot(k[4,:], MV[4,:], 'c')
axes.plot(k[5,:], MV[5,:], 'b')

axes.set_xlabel(r'$\Delta$', fontsize = 16)
axes.set_ylabel(r'$\sigma^n_{BS}(k,t)$', fontsize = 16)
axes.set_title(r'$\rho = -0.90 \quad \alpha = -0.00$', fontsize = 16)
# axes.legend([r'$\mathsf{1D}$',
#              r'$\mathsf{1W}$',
#              r'$\mathsf{1M}$',
#              r'$\mathsf{3M}$',
#              r'$\mathsf{6M}$',
#              r'$\mathsf{1Y}$'])
plt.xlim([0,1])
plt.ylim([0.10,0.35])
plt.grid(True)

# %%
surface = Surface('surface', 'both', close = False)
surface.surface
# Out:
#           5P       10P       15P       20P       25P       30P       35P  \
# 1D  0.234946  0.235205  0.235203  0.235243  0.235229  0.235172  0.235073
# 1W  0.235982  0.235565  0.235246  0.235066  0.234911  0.234747  0.234580
# 1M  0.239632  0.236776  0.235235  0.234262  0.233561  0.233022  0.232613
# 3M  0.247374  0.238886  0.234552  0.231756  0.229798  0.228449  0.227516
# 6M  0.255714  0.240177  0.232269  0.227291  0.223919  0.221587  0.220032
# 1Y  0.264201  0.238111  0.225134  0.217133  0.211845  0.208244  0.205873
#
#          40P       45P       ATM       45C       40C       35C       30C  \
# 1D  0.234990  0.234980  0.234979  0.234980  0.234998  0.235090  0.235183
# 1W  0.234463  0.234424  0.234414  0.234434  0.234497  0.234636  0.234795
# 1M  0.232357  0.232211  0.232185  0.232293  0.232498  0.232829  0.233263
# 3M  0.226927  0.226639  0.226596  0.226911  0.227450  0.228296  0.229480
# 6M  0.219086  0.218665  0.218632  0.219257  0.220278  0.221856  0.224089
# ...

# %%
k = np.array(surface._log_strike_surface())
MV = np.array(surface.surface)

plot, axes = plt.subplots(figsize=(4,2.5))

axes.plot(k[0,:], MV[0,:], 'r')
axes.plot(k[1,:], MV[1,:], 'm')
axes.plot(k[2,:], MV[2,:], 'y')
axes.plot(k[3,:], MV[3,:], 'g')
axes.plot(k[4,:], MV[4,:], 'c')
axes.plot(k[5,:], MV[5,:], 'b')

axes.set_xlabel(r'$k$', fontsize = 16)
axes.set_ylabel(r'$\sigma_{BS}(k,t)$', fontsize = 16)
axes.set_title(r'$\rho = 0, \quad \alpha = 0$', fontsize = 16)
# axes.legend([r'$\mathsf{1D}$',
#              r'$\mathsf{1W}$',
#              r'$\mathsf{1M}$',
#              r'$\mathsf{3M}$',
#              r'$\mathsf{6M}$',
#              r'$\mathsf{1Y}$'])
plt.xlim([-0.4,0.4])
plt.ylim([0.20,0.28])
axes.yaxis.set_ticks(np.arange(0.2, 0.28, 0.02))
plt.grid(True)

fname = '/Users/ryanmccrickerd/Desktop/phd/2017-18/turbo/surface3.pdf'
plt.savefig(fname, dpi=300, bbox_inches='tight')

# %%
k = np.array(surface._put_deltas())
MV = np.array(surface.surface)

plot, axes = plt.subplots(dpi=10000, figsize=(4,2.5))

axes.plot(k[0,:], MV[0,:], 'r')
axes.plot(k[1,:], MV[1,:], 'm')
axes.plot(k[2,:], MV[2,:], 'y')
axes.plot(k[3,:], MV[3,:], 'g')
axes.plot(k[4,:], MV[4,:], 'c')
axes.plot(k[5,:], MV[5,:], 'b')

axes.set_xlabel(r'$\Delta$', fontsize = 16)
axes.set_ylabel(r'$\sigma^n_{BS}(k,t)$', fontsize = 16)
axes.set_title(r'$\rho = -0.00 \quad \alpha = -0.00$', fontsize = 16)
# axes.legend([r'$\mathsf{1D}$',
#              r'$\mathsf{1W}$',
#              r'$\mathsf{1M}$',
#              r'$\mathsf{3M}$',
#              r'$\mathsf{6M}$',
#              r'$\mathsf{1Y}$'])
plt.xlim([0,1])
plt.ylim([0.20,0.28])
axes.yaxis.set_ticks(np.arange(0.2, 0.28, 0.02))
plt.grid(True)
